# %% [markdown]
# # Same Affines, but different CRS!
#
# Here is a case for needing to account for both affine and CRS. Sentinel-2 is delivered on the MGRS grid, which divides UTM Zones into smaller units. Adjacent zones have the same affines, and therefore appear to have the same coordinates. But the CRS differentiates them.

# %%
import os 
import xarray as xr 
import pystac
os.environ['VSICURL_PC_URL_SIGNING']='YES'
os.environ['GDAL_DISABLE_READDIR_ON_OPEN'] = 'EMPTY_DIR'

# %matplotlib inline

# %%
def load_raster(url, asset='B04', overview_level=3, masked=True):
    item = pystac.read_file(url)
    href = item.assets[asset].href
    da = xr.open_dataarray(href, 
                           engine='rasterio', 
                           masked=masked,
                           open_kwargs=dict(overview_level=overview_level),
                           chunks='auto').squeeze()
    return da

# %%
# MGRS Tile 10TDS
url = 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/sentinel-2-l2a/items/S2C_MSIL2A_20250414T190931_R056_T10TDS_20250415T001314'
da1 = load_raster(url)
da1
# Out:
# <xarray.DataArray 'band_data' (y: 687, x: 687)> Size: 2MB
# dask.array<getitem, shape=(687, 687), dtype=float32, chunksize=(687, 687), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 5kB 4e+05 4.002e+05 ... 5.095e+05 5.097e+05
#   * y            (y) float64 5kB 5.2e+06 5.2e+06 5.2e+06 ... 5.09e+06 5.09e+06
#     spatial_ref  int64 8B ...
# Attributes:
#     AREA_OR_POINT:  Area

# %%
# MGRS Tile 11TMM
url = 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/sentinel-2-l2a/items/S2B_MSIL2A_20250413T184919_R113_T11TMM_20250413T224733'
da2 = load_raster(url)

# %%
da1.rio.crs == da2.rio.crs
# Out:
# False

# %%
print(da1.rio.crs.to_epsg(), da2.rio.crs.to_epsg())
# Out:
# 32610 32611

# %%
da1.rio.transform() == da2.rio.transform()
# Out:
# True

# %%
# This should raise and error b/c not in fact aligned!
da1 + da2
# Out:
# <xarray.DataArray 'band_data' (y: 687, x: 687)> Size: 2MB
# dask.array<add, shape=(687, 687), dtype=float32, chunksize=(687, 687), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 5kB 4e+05 4.002e+05 ... 5.095e+05 5.097e+05
#   * y            (y) float64 5kB 5.2e+06 5.2e+06 5.2e+06 ... 5.09e+06 5.09e+06
#     spatial_ref  int64 8B 0

# %% [markdown]
# ## Take advantage of xproj CRSIndex

# %%
## WIth xproj
#!pip install xproj
import xproj

# %%
da1p = da1.proj.assign_crs(da1.rio.crs)
da2p = da1.proj.assign_crs(da2.rio.crs)

# %%
da1p + da2p
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 da1p + da2p
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/_typed_ops.py:528, in DataArrayOpsMixin.__add__(self, other)
#     527 def __add__(self, other: DaCompatible) -> Self | Dataset | DataTree:
# --> 528     return self._binary_op(other, operator.add)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/dataarray.py:4861, in DataArray._binary_op(self, other, f, reflexive)
#    4854 other_coords = getattr(other, "coords", None)
#    4856 variable = (
#    4857     f(self.variable, other_variable_or_arraylike)
#    4858     if not reflexive
#    4859     else f(other_variable_or_arraylike, self.variable)
#    4860 )
# -> 4861 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4862 name = result_name([self, other])
#    4864 return self._replace(variable, coords, name, indexes=indexes)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/coordinates.py:505, in Coordinates._merge_raw(self, other, reflexive)
#     503 else:
#     504     coord_list = [self, other] if not reflexive else [other, self]
# --> 505     variables, indexes = merge_coordinates_without_align(coord_list)
#     506 return variables, indexes
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/structure/merge.py:418, in merge_coordinates_without_align(objects, prioritized, exclude_dims, combine_attrs)
#     414     filtered = collected
#     416 # TODO: indexes should probably be filtered in collected elements
#     417 # before merging them
# --> 418 merged_coords, merged_indexes = merge_collected(
#     419     filtered, prioritized, combine_attrs=combine_attrs
#     420 )
#     421 merged_indexes = filter_indexes_from_coords(merged_indexes, set(merged_coords))
#     423 return merged_coords, merged_indexes
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/structure/merge.py:274, in merge_collected(grouped, prioritized, compat, combine_attrs, equals)
#     270 for other_var, other_index in indexed_elements[1:]:
#     271     if not indexes_equal(
#     272         index, other_index, variable, other_var, index_cmp_cache
#     273     ):
# --> 274         raise MergeError(
#     275             f"conflicting values/indexes on objects to be combined for coordinate {name!r}\n"
#     276             f"first index: {index!r}\nsecond index: {other_index!r}\n"
#     277             f"first variable: {variable!r}\nsecond variable: {other_var!r}\n"
#     278         )
#     279 if compat == "identical":
#     280     for other_variable, _ in indexed_elements[1:]:
#
# MergeError: conflicting values/indexes on objects to be combined for coordinate 'init'
# first index: CRSIndex
# <Projected CRS: EPSG:32610>
# Name: WGS 84 / UTM zone 10N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 126°W and 120°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - British Columbia (BC); Northwest Territories (NWT); Nunavut; Yukon. United States (USA) - Alaska (AK).
# - bounds: (-126.0, 0.0, -120.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 10N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
#
# second index: CRSIndex
# <Projected CRS: EPSG:32611>
# Name: WGS 84 / UTM zone 11N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 120°W and 114°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - Alberta; British Columbia (BC); Northwest Territories (NWT); Nunavut. Mexico. United States (USA).
# - bounds: (-120.0, 0.0, -114.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 11N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
#
# first variable: <xarray.Variable ()> Size: 8B
# array(0)
# second variable: <xarray.Variable ()> Size: 8B
# array(0)
