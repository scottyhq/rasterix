# %% [markdown]
# # Xarray Raster Alignment Example
#
# Same CRS, but offset Affines

# %% [markdown]
# ## No RasterIndex

# %%
import xarray as xr
import os
os.environ['GDAL_DISABLE_READDIR_ON_OPEN'] = 'EMPTY_DIR'

# %%
# Same acquisition data 
# same CRS but different resolution & therefore different affines
b4 = 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/36/M/YB/2020/8/S2A_36MYB_20200814_0_L2A/B04.tif'
b5 = 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/36/M/YB/2020/8/S2A_36MYB_20200814_0_L2A/B05.tif'

# %%
red = xr.open_dataarray(b4, engine='rasterio', chunks='auto').squeeze()
red
# Out:
# <xarray.DataArray 'band_data' (y: 10980, x: 10980)> Size: 482MB
# dask.array<getitem, shape=(10980, 10980), dtype=float32, chunksize=(5120, 5120), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 88kB 7e+05 7e+05 7e+05 ... 8.097e+05 8.098e+05
#   * y            (y) float64 88kB 9.7e+06 9.7e+06 9.7e+06 ... 9.59e+06 9.59e+06
#     spatial_ref  int64 8B ...
# Attributes:
#     OVR_RESAMPLING_ALG:  AVERAGE
#     AREA_OR_POINT:       Area

# %%
red_edge = xr.open_dataarray(b5, engine='rasterio', chunks='auto').squeeze()
red_edge
# Out:
# <xarray.DataArray 'band_data' (y: 5490, x: 5490)> Size: 121MB
# dask.array<getitem, shape=(5490, 5490), dtype=float32, chunksize=(5490, 5490), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 44kB 7e+05 7e+05 7e+05 ... 8.097e+05 8.098e+05
#   * y            (y) float64 44kB 9.7e+06 9.7e+06 9.7e+06 ... 9.59e+06 9.59e+06
#     spatial_ref  int64 8B ...
# Attributes:
#     OVR_RESAMPLING_ALG:  AVERAGE
#     AREA_OR_POINT:       Area

# %%
# Both same UTM Zone
red.rio.crs.to_epsg()
# Out:
# 32736

# %%
red_edge.rio.crs == red.rio.crs
# Out:
# True

# %%
red_edge.rio.transform()
# Out:
# Affine(20.0, 0.0, 699960.0,
#        0.0, -20.0, 9700000.0)

# %%
red.rio.transform()
# Out:
# Affine(10.0, 0.0, 699960.0,
#        0.0, -10.0, 9700000.0)

# %% [markdown]
# ### Raise warning here?

# %%
# Naive pixel band ratio (might expect automatic coarsening here)
# Could be good to raise warning if *affine* not the same
red / red_edge
# Out:
# <xarray.DataArray 'band_data' (y: 0, x: 0)> Size: 0B
# dask.array<truediv, shape=(0, 0), dtype=float32, chunksize=(0, 0), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 0B
#   * y            (y) float64 0B
#     band         int64 8B 1
#     spatial_ref  int64 8B 0

# %%
# An aside / special case but COGs have pre-computed overviews which 
# often match the lower resolution coordinates of other bands
# it could be neat if the engine were 'aware' of these !
red_ovr2 = xr.open_dataarray(b4,
                               engine='rasterio', 
                               open_kwargs=dict(overview_level=0), 
                               chunks='auto').squeeze()

# %%
red_ovr2 + red_edge
# Out:
# <xarray.DataArray 'band_data' (y: 5490, x: 5490)> Size: 121MB
# dask.array<add, shape=(5490, 5490), dtype=float32, chunksize=(5490, 5490), chunktype=numpy.ndarray>
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 44kB 7e+05 7e+05 7e+05 ... 8.097e+05 8.098e+05
#   * y            (y) float64 44kB 9.7e+06 9.7e+06 9.7e+06 ... 9.59e+06 9.59e+06
#     spatial_ref  int64 8B 0

# %% [markdown]
# ## With RasterIndex !

# %%
# TODO: rasterix pyproject
import sys
sys.path.append("..")
from rasterix import RasterIndex

# %%
def set_raster_index(obj):
    """Return a new DataArray or Dataset with a RasterIndex."""
    x_dim = obj.rio.x_dim
    y_dim = obj.rio.y_dim

    index = RasterIndex.from_transform(
        obj.rio.transform(),
        obj.sizes[x_dim],
        obj.sizes[y_dim],
        x_dim=x_dim,
        y_dim=y_dim,
    )

    # drop-in replacement of explicit x/y coordinates for now
    coords = xr.Coordinates.from_xindex(index)
    return obj.assign_coords(coords)


red_i = set_raster_index(red)
red_edge_i = set_raster_index(red_edge)

# %%
red_i / red_edge_i
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 red_i / red_edge_i
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/_typed_ops.py:576, in DataArrayOpsMixin.__truediv__(self, other)
#     575 def __truediv__(self, other: DaCompatible) -> Self | Dataset | DataTree:
# --> 576     return self._binary_op(other, operator.truediv)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/dataarray.py:4852, in DataArray._binary_op(self, other, f, reflexive)
#    4850 if isinstance(other, DataArray):
#    4851     align_type = OPTIONS["arithmetic_join"]
# -> 4852     self, other = align(self, other, join=align_type, copy=False)
#    4853 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4854 other_coords = getattr(other, "coords", None)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/structure/alignment.py:883, in align(join, copy, indexes, exclude, fill_value, *objects)
#     687 """
#     688 Given any number of Dataset and/or DataArray objects, returns new
#     689 objects with aligned indexes and dimension sizes.
#    (...)
#     873
#     874 """
#     875 aligner = Aligner(
#     876     objects,
#     877     join=join,
#    (...)
#     881     fill_value=fill_value,
#     882 )
# --> 883 aligner.align()
#     884 return aligner.results
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/structure/alignment.py:575, in Aligner.align(self)
#     573 self.find_matching_unindexed_dims()
#     574 self.assert_no_index_conflict()
# --> 575 self.align_indexes()
#     576 self.assert_unindexed_dim_sizes_equal()
#     578 if self.join == "override":
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/structure/alignment.py:429, in Aligner.align_indexes(self)
#     422     raise ValueError(
#     423         "cannot align objects with join='exact' where "
#     424         "index/labels/sizes are not equal along "
#     425         "these coordinates (dimensions): "
#     426         + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     427     )
#     428 joiner = self._get_index_joiner(index_cls)
# --> 429 joined_index = joiner(matching_indexes)
#     430 if self.join == "left":
#     431     joined_index_vars = matching_index_vars[0]
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/core/indexes.py:285, in Index.join(self, other, how)
#     267 def join(self, other: Self, how: JoinOptions = "inner") -> Self:
#     268     """Return a new index from the combination of this index with another
#     269     index of the same type.
#     270
#    (...)
#     283         A new Index object.
#     284     """
# --> 285     raise NotImplementedError(
#     286         f"{self!r} doesn't support alignment with inner/outer join method"
#     287     )
#
# NotImplementedError: RasterIndex
# 'x':
#     <rasterix.raster_index.AxisAffineTransformIndex object at 0x7fdf81e95e90>
# 'y':
#     <rasterix.raster_index.AxisAffineTransformIndex object at 0x7fdf78aca850> doesn't support alignment with inner/outer join method
